# %%
import os
import numpy as np
import h5py
from random import *
import random

# %% [markdown]
# y가 클수록 바닥쪽
#
# label 1:  { 107, -107}
# label 2:  { 53, -53}
# label 3:  { 120, -120}
# label 4:  { 64.5, -64.5}
# label 5:  { 193, -193}

# %%
datafolder=os.listdir("./data")
#label 일치하는애 찾고, 랜덤시드 일치하는애 찾고,
flist=os.listdir("./data/npy_10000/list")
max_shards=20
for file in flist:
    if 'filelist_1' in file: #file = filelist_1_shards_randomseed_F
        fstr=file.split('_') #{filelist, 1, shards, randomseed, F}
        filenames=[line.rstrip() for line in open("./data/npy_10000/list/"+file, 'r')] # filenames = generated_shards_0_randomseed_part_partnum.npy
        a_real_seg=np.zeros((len(filenames),3), dtype=np.uint8)
        temp_real_seg=[]
        for i in range(0,len(filenames)):
            if filenames[i]=="":
                continue
            npydata=np.load("./data/npy_10000/one/"+filenames[i]+".npy")
            temp_j_seg=[0,0,0]
            for k in range(len(npydata[:,1])):
                seg=[0,0,0]
                if npydata[k,1] >=107:
                    seg[0] = 1
                elif npydata[k,1] < -107:
                    seg[2] = 1
                else:
                    seg[1] = 1
                for j in range(len(seg)):
                    if seg[j] > temp_j_seg[j]:
                        temp_j_seg[j]=seg[j]
                    else:
                        temp_j_seg[j]=temp_j_seg[j]    
            temp_real_seg.append(temp_j_seg)
                
        if len(temp_real_seg) < max_shards:
            for i in range(max_shards-len(temp_real_seg)):
                temp_shuffle_seg=temp_real_seg
                temp_real_seg.append(int(fstr[1])-1)
                temp_real_seg.append(temp_shuffle_seg[randrange(len(temp_shuffle_seg))])
        a_real_seg=np.array(temp_real_seg)
        f=h5py.File("./data/"+str(fstr[1])+'_'+str(fstr[2])+'_'+str(fstr[3])+".h5",'a')
        real_seg=f.create_dataset("real_seg", data=a_real_seg)
        f.close()

# %%
datafolder=os.listdir("./data")
#label 일치하는애 찾고, 랜덤시드 일치하는애 찾고,
flist=os.listdir("./data/npy_10000/list")
max_shards=20
for file in flist:
    if 'filelist_2' in file: #file = filelist_1_shards_randomseed_F
        fstr=file.split('_') #{filelist, 1, shards, randomseed, F}
        filenames=[line.rstrip() for line in open("./data/npy_10000/list/"+file, 'r')] # filenames = generated_shards_0_randomseed_part_partnum.npy
        a_real_seg=np.zeros((len(filenames),3), dtype=np.uint8)
        temp_real_seg=[]
        for i in range(0,len(filenames)):
            if filenames[i]=="":
                continue
            npydata=np.load("./data/npy_10000/two/"+filenames[i]+".npy")
            temp_j_seg=[0,0,0]
            for k in range(len(npydata[:,1])):
                seg=[0,0,0]
                if npydata[k,1] >=53:
                    seg[0] = 1
                elif npydata[k,1] < -53:
                    seg[2] = 1
                else:
                    seg[1] = 1
                for j in range(len(seg)):
                    if seg[j] > temp_j_seg[j]:
                        temp_j_seg[j]=seg[j]
                    else:
                        temp_j_seg[j]=temp_j_seg[j]    
            temp_real_seg.append(temp_j_seg)
                
        if len(temp_real_seg) < max_shards:
            for i in range(max_shards-len(temp_real_seg)):
                temp_shuffle_seg=temp_real_seg
                temp_real_seg.append(int(fstr[1])-1)
                temp_real_seg.append(temp_shuffle_seg[randrange(len(temp_shuffle_seg))])
        a_real_seg=np.array(temp_real_seg)
        f=h5py.File("./data/"+str(fstr[1])+'_'+str(fstr[2])+'_'+str(fstr[3])+".h5",'a')
        real_seg=f.create_dataset("real_seg", data=a_real_seg)
        f.close()

# %%
datafolder=os.listdir("./data")
#label 일치하는애 찾고, 랜덤시드 일치하는애 찾고,
flist=os.listdir("./data/npy_10000/list")
max_shards=20
for file in flist:
    if 'filelist_3' in file: #file = filelist_1_shards_randomseed_F
        fstr=file.split('_') #{filelist, 1, shards, randomseed, F}
        filenames=[line.rstrip() for line in open("./data/npy_10000/list/"+file, 'r')] # filenames = generated_shards_0_randomseed_part_partnum.npy
        a_real_seg=np.zeros((len(filenames),3), dtype=np.uint8)
        temp_real_seg=[]
        for i in range(0,len(filenames)):
            if filenames[i]=="":
                continue
            npydata=np.load("./data/npy_10000/three/"+filenames[i]+".npy")
            temp_j_seg=[0,0,0]
            for k in range(len(npydata[:,1])):
                seg=[0,0,0]
                if npydata[k,1] >=120:
                    seg[0] = 1
                elif npydata[k,1] < -120:
                    seg[2] = 1
                else:
                    seg[1] = 1
                for j in range(len(seg)):
                    if seg[j] > temp_j_seg[j]:
                        temp_j_seg[j]=seg[j]
                    else:
                        temp_j_seg[j]=temp_j_seg[j]    
            temp_real_seg.append(temp_j_seg)
                
        if len(temp_real_seg) < max_shards:
            for i in range(max_shards-len(temp_real_seg)):
                temp_shuffle_seg=temp_real_seg
                temp_real_seg.append(int(fstr[1])-1)
                temp_real_seg.append(temp_shuffle_seg[randrange(len(temp_shuffle_seg))])
        a_real_seg=np.array(temp_real_seg)
        f=h5py.File("./data/"+str(fstr[1])+'_'+str(fstr[2])+'_'+str(fstr[3])+".h5",'a')
        real_seg=f.create_dataset("real_seg", data=a_real_seg)
        f.close()

# %%
datafolder=os.listdir("./data")
#label 일치하는애 찾고, 랜덤시드 일치하는애 찾고,
flist=os.listdir("./data/npy_10000/list")
max_shards=20
for file in flist:
    if 'filelist_4' in file: #file = filelist_1_shards_randomseed_F
        fstr=file.split('_') #{filelist, 1, shards, randomseed, F}
        filenames=[line.rstrip() for line in open("./data/npy_10000/list/"+file, 'r')] # filenames = generated_shards_0_randomseed_part_partnum.npy
        a_real_seg=np.zeros((len(filenames),3), dtype=np.uint8)
        temp_real_seg=[]
        for i in range(0,len(filenames)):
            if filenames[i]=="":
                continue
            npydata=np.load("./data/npy_10000/four/"+filenames[i]+".npy")
            temp_j_seg=[0,0,0]
            for k in range(len(npydata[:,1])):
                seg=[0,0,0]
                if npydata[k,1] >=64.5:
                    seg[0] = 1
                elif npydata[k,1] < -64.5:
                    seg[2] = 1
                else:
                    seg[1] = 1
                for j in range(len(seg)):
                    if seg[j] > temp_j_seg[j]:
                        temp_j_seg[j]=seg[j]
                    else:
                        temp_j_seg[j]=temp_j_seg[j]    
            temp_real_seg.append(temp_j_seg)
                
        if len(temp_real_seg) < max_shards:
            for i in range(max_shards-len(temp_real_seg)):
                temp_shuffle_seg=temp_real_seg
                temp_real_seg.append(int(fstr[1])-1)
                temp_real_seg.append(temp_shuffle_seg[randrange(len(temp_shuffle_seg))])
        a_real_seg=np.array(temp_real_seg)
        f=h5py.File("./data/"+str(fstr[1])+'_'+str(fstr[2])+'_'+str(fstr[3])+".h5",'a')
        real_seg=f.create_dataset("real_seg", data=a_real_seg)
        f.close()

# %%
datafolder=os.listdir("./data")
#label 일치하는애 찾고, 랜덤시드 일치하는애 찾고,
flist=os.listdir("./data/npy_10000/list")
max_shards=20
for file in flist:
    if 'filelist_5' in file: #file = filelist_1_shards_randomseed_F
        fstr=file.split('_') #{filelist, 1, shards, randomseed, F}
        filenames=[line.rstrip() for line in open("./data/npy_10000/list/"+file, 'r')] # filenames = generated_shards_0_randomseed_part_partnum.npy
        a_real_seg=np.zeros((len(filenames),3), dtype=np.uint8)
        temp_real_seg=[]
        for i in range(0,len(filenames)):
            if filenames[i]=="":
                continue
            npydata=np.load("./data/npy_10000/five/"+filenames[i]+".npy")
            temp_j_seg=[0,0,0]
            for k in range(len(npydata[:,1])):
                seg=[0,0,0]
                if npydata[k,1] >=193:
                    seg[0] = 1
                elif npydata[k,1] < -193:
                    seg[2] = 1
                else:
                    seg[1] = 1
                for j in range(len(seg)):
                    if seg[j] > temp_j_seg[j]:
                        temp_j_seg[j]=seg[j]
                    else:
                        temp_j_seg[j]=temp_j_seg[j]    
            temp_real_seg.append(temp_j_seg)
                
        if len(temp_real_seg) < max_shards:
            for i in range(max_shards-len(temp_real_seg)):
                temp_shuffle_seg=temp_real_seg
                temp_real_seg.append(int(fstr[1])-1)
                temp_real_seg.append(temp_shuffle_seg[randrange(len(temp_shuffle_seg))])
        a_real_seg=np.array(temp_real_seg)
        f=h5py.File("./data/"+str(fstr[1])+'_'+str(fstr[2])+'_'+str(fstr[3])+".h5",'a')
        real_seg=f.create_dataset("real_seg", data=a_real_seg)
        f.close()

# %% [markdown]
# ---
#
# y가 클수록 바닥쪽
#
# label 1:
# { 239.014 -239.014
#              108.732 -108.358
#              239.014 -239.014}
# label 2:
# { 213.981 -213.981
#              53.668 -53.680
#              213.981 -213.981}
# label 3:
# { 208.976 -208.976
#              120.316 -120.309
#              208.976 -208.976}
# label 4:
# { 219.977 -219.977
#              64.908 -64.943
#              219.977 -219.977}
# label 5:
# {960.863 -960.863
#             194.373 -194.371
#              960.863 -960.863}
#
# **centralized data & continuous segmentation label ( max, mean, min )**

# %%
flist=os.listdir("./data/npy_10000/list")
max_shards=20
ymax, ymin=108.732,-108.358
for file in flist:
    if 'filelist_1' in file: #file = filelist_1_shards_randomseed_F
        fstr=file.split('_') #{filelist, 1, shards, randomseed, F}
        filenames=[line.rstrip() for line in open("./data/npy_10000/list/"+file, 'r')] # filenames = generated_shards_0_randomseed_part_partnum
        a_data=np.zeros((len(filenames),2048,3))
        a_label=np.zeros((len(filenames),1),dtype=np.uint8)
        a_seg=np.zeros((len(filenames),3), dtype=np.float64)
        temp_list=[]
        temp_label=[]
        temp_seg=[]        
        for i in range(0,len(filenames)):
            if filenames[i]=="":
                continue
            npydata=np.load("./data/npy_10000/one/"+filenames[i]+".npy")
            np.random.shuffle(npydata)
            if npydata.shape[0]<2048:
                continue
            else:
                #x,y,z 2048 samping
                temp_j_list=[]
                for j in range(0,2048):
                    temp_j_list.append([npydata[j][0],npydata[j][1], npydata[j][2]])
                # seg_label ∈ [0,1]
                temp_j_seg=[0,0,0]
                temp_j_seg[0]=(np.amax(npydata[:,1])-ymin)/(ymax-ymin)
                temp_j_seg[1]=(np.mean(npydata[:,1])-ymin)/(ymax-ymin)
                temp_j_seg[2]=(np.amin(npydata[:,1])-ymin)/(ymax-ymin)
                    
                temp_list.append(temp_j_list)
                temp_label.append(int(fstr[1])-1)
                temp_seg.append(temp_j_seg)
                
        if len(temp_list) < max_shards:
            for i in range(max_shards-len(temp_list)):
                temp_shuffle_list=temp_list
                temp_shuffle_seg=temp_seg
                rvalue=randrange(len(temp_shuffle_list))
                temp_list.append(temp_shuffle_list[rvalue])
                temp_label.append(int(fstr[1])-1)
                temp_seg.append(temp_shuffle_seg[rvalue])

            
        a_data=np.array(temp_list)
        a_label=np.transpose(np.array(temp_label))
        a_seg=np.array(temp_seg)
        
        target=np.zeros(a_data.shape)
        for i in range(a_data.shape[0]):
            for j in range(a_data.shape[1]):
                for k in range(a_data.shape[2]):
                    target[i][j][k]=a_data[i][j][k]-a_data[i].mean(axis=0)[k]

        f=h5py.File("./data/floatlabel/"+str(fstr[1])+'_'+str(fstr[2])+'_'+str(fstr[3])+".h5",'w')
        data=f.create_dataset("data", data=target)
        label=f.create_dataset("label", data=a_label)
        seg=f.create_dataset("seg", data=a_seg)
        f.close()

# %%
flist=os.listdir("./data/npy_10000/list")
max_shards=20
ymax, ymin=53.668, -53.680
for file in flist:
    if 'filelist_2' in file: #file = filelist_2_shards_randomseed_F
        fstr=file.split('_') #{filelist, 2, shards, randomseed, F}
        filenames=[line.rstrip() for line in open("./data/npy_10000/list/"+file, 'r')] # filenames = generated_shards_0_randomseed_part_partnum
        a_data=np.zeros((len(filenames),2048,3))
        a_label=np.zeros((len(filenames),1),dtype=np.uint8)
        a_seg=np.zeros((len(filenames),1), dtype=np.float64)
        temp_list=[]
        temp_label=[]
        temp_seg=[]        
        for i in range(0,len(filenames)):
            if filenames[i]=="":
                continue
            npydata=np.load("./data/npy_10000/two/"+filenames[i]+".npy")
            np.random.shuffle(npydata)
            if npydata.shape[0]<2048:
                continue
            else:
                #x,y,z 2048 samping
                temp_j_list=[]
                for j in range(0,2048):
                    temp_j_list.append([npydata[j][0],npydata[j][1], npydata[j][2]])
                # seg_label ∈ [0,1]
                temp_j_seg=[0,0,0]
                temp_j_seg[0]=(np.amax(npydata[:,1])-ymin)/(ymax-ymin)
                temp_j_seg[1]=(np.mean(npydata[:,1])-ymin)/(ymax-ymin)
                temp_j_seg[2]=(np.amin(npydata[:,1])-ymin)/(ymax-ymin)       
                
                temp_list.append(temp_j_list)
                temp_label.append(int(fstr[1])-1)
                temp_seg.append(temp_j_seg)
                
        if len(temp_list) < max_shards:
            for i in range(max_shards-len(temp_list)):
                temp_shuffle_list=temp_list
                temp_shuffle_seg=temp_seg
                rvalue=randrange(len(temp_shuffle_list))
                temp_list.append(temp_shuffle_list[rvalue])
                temp_label.append(int(fstr[1])-1)
                temp_seg.append(temp_shuffle_seg[rvalue])

            
        a_data=np.array(temp_list)
        a_label=np.transpose(np.array(temp_label))
        a_seg=np.array(temp_seg)
        
        target=np.zeros(a_data.shape)
        for i in range(a_data.shape[0]):
            for j in range(a_data.shape[1]):
                for k in range(a_data.shape[2]):
                    target[i][j][k]=a_data[i][j][k]-a_data[i].mean(axis=0)[k]

        f=h5py.File("./data/floatlabel/"+str(fstr[1])+'_'+str(fstr[2])+'_'+str(fstr[3])+".h5",'w')
        data=f.create_dataset("data", data=target)
        label=f.create_dataset("label", data=a_label)
        seg=f.create_dataset("seg", data=a_seg)
        f.close()

# %%
flist=os.listdir("./data/npy_10000/list")
max_shards=20
ymax, ymin=120.316, -120.309
for file in flist:
    if 'filelist_3' in file: #file = filelist_3_shards_randomseed_F
        fstr=file.split('_') #{filelist, 3, shards, randomseed, F}
        filenames=[line.rstrip() for line in open("./data/npy_10000/list/"+file, 'r')] # filenames = generated_shards_0_randomseed_part_partnum
        a_data=np.zeros((len(filenames),2048,3))
        a_label=np.zeros((len(filenames),1),dtype=np.uint8)
        a_seg=np.zeros((len(filenames),1), dtype=np.float64)
        temp_list=[]
        temp_label=[]
        temp_seg=[]        
        for i in range(0,len(filenames)):
            if filenames[i]=="":
                continue
            npydata=np.load("./data/npy_10000/three/"+filenames[i]+".npy")
            np.random.shuffle(npydata)
            if npydata.shape[0]<2048:
                continue
            else:
                #x,y,z 2048 samping
                temp_j_list=[]
                for j in range(0,2048):
                    temp_j_list.append([npydata[j][0],npydata[j][1], npydata[j][2]])
                # seg_label ∈ [0,1]
                temp_j_seg=[0,0,0]
                temp_j_seg[0]=(np.amax(npydata[:,1])-ymin)/(ymax-ymin)
                temp_j_seg[1]=(np.mean(npydata[:,1])-ymin)/(ymax-ymin)
                temp_j_seg[2]=(np.amin(npydata[:,1])-ymin)/(ymax-ymin) 
                    
                temp_list.append(temp_j_list)
                temp_label.append(int(fstr[1])-1)
                temp_seg.append(temp_j_seg)
                
        if len(temp_list) < max_shards:
            for i in range(max_shards-len(temp_list)):
                temp_shuffle_list=temp_list
                temp_shuffle_seg=temp_seg
                rvalue=randrange(len(temp_shuffle_list))
                temp_list.append(temp_shuffle_list[rvalue])
                temp_label.append(int(fstr[1])-1)
                temp_seg.append(temp_shuffle_seg[rvalue])

            
        a_data=np.array(temp_list)
        a_label=np.transpose(np.array(temp_label))
        a_seg=np.array(temp_seg)
        
        target=np.zeros(a_data.shape)
        for i in range(a_data.shape[0]):
            for j in range(a_data.shape[1]):
                for k in range(a_data.shape[2]):
                    target[i][j][k]=a_data[i][j][k]-a_data[i].mean(axis=0)[k]

        f=h5py.File("./data/floatlabel/"+str(fstr[1])+'_'+str(fstr[2])+'_'+str(fstr[3])+".h5",'w')
        data=f.create_dataset("data", data=target)
        label=f.create_dataset("label", data=a_label)
        seg=f.create_dataset("seg", data=a_seg)
        f.close()

# %%
flist=os.listdir("./data/npy_10000/list")
max_shards=20
ymax, ymin=64.908, -64.943
for file in flist:
    if 'filelist_4' in file: #file = filelist_4_shards_randomseed_F
        fstr=file.split('_') #{filelist, 4, shards, randomseed, F}
        filenames=[line.rstrip() for line in open("./data/npy_10000/list/"+file, 'r')] # filenames = generated_shards_0_randomseed_part_partnum
        a_data=np.zeros((len(filenames),2048,3))
        a_label=np.zeros((len(filenames),1),dtype=np.uint8)
        a_seg=np.zeros((len(filenames),1), dtype=np.float64)
        temp_list=[]
        temp_label=[]
        temp_seg=[]        
        for i in range(0,len(filenames)):
            if filenames[i]=="":
                continue
            npydata=np.load("./data/npy_10000/four/"+filenames[i]+".npy")
            np.random.shuffle(npydata)
            if npydata.shape[0]<2048:
                continue
            else:
                #x,y,z 2048 samping
                temp_j_list=[]
                for j in range(0,2048):
                    temp_j_list.append([npydata[j][0],npydata[j][1], npydata[j][2]])
                # seg_label ∈ [0,1]
                temp_j_seg=[0,0,0]
                temp_j_seg[0]=(np.amax(npydata[:,1])-ymin)/(ymax-ymin)
                temp_j_seg[1]=(np.mean(npydata[:,1])-ymin)/(ymax-ymin)
                temp_j_seg[2]=(np.amin(npydata[:,1])-ymin)/(ymax-ymin) 
                    
                temp_list.append(temp_j_list)
                temp_label.append(int(fstr[1])-1)
                temp_seg.append(temp_j_seg)
                
        if len(temp_list) < max_shards:
            for i in range(max_shards-len(temp_list)):
                temp_shuffle_list=temp_list
                temp_shuffle_seg=temp_seg
                rvalue=randrange(len(temp_shuffle_list))
                temp_list.append(temp_shuffle_list[rvalue])
                temp_label.append(int(fstr[1])-1)
                temp_seg.append(temp_shuffle_seg[rvalue])

            
        a_data=np.array(temp_list)
        a_label=np.transpose(np.array(temp_label))
        a_seg=np.array(temp_seg)
        
        target=np.zeros(a_data.shape)
        for i in range(a_data.shape[0]):
            for j in range(a_data.shape[1]):
                for k in range(a_data.shape[2]):
                    target[i][j][k]=a_data[i][j][k]-a_data[i].mean(axis=0)[k]

        f=h5py.File("./data/floatlabel/"+str(fstr[1])+'_'+str(fstr[2])+'_'+str(fstr[3])+".h5",'w')
        data=f.create_dataset("data", data=target)
        label=f.create_dataset("label", data=a_label)
        seg=f.create_dataset("seg", data=a_seg)
        f.close()

# %%
flist=os.listdir("./data/npy_10000/list")
max_shards=20
ymax, ymin=194.373, -194.371
for file in flist:
    if 'filelist_5' in file: #file = filelist_5_shards_randomseed_F
        fstr=file.split('_') #{filelist, 5, shards, randomseed, F}
        filenames=[line.rstrip() for line in open("./data/npy_10000/list/"+file, 'r')] # filenames = generated_shards_0_randomseed_part_partnum
        a_data=np.zeros((len(filenames),2048,3))
        a_label=np.zeros((len(filenames),1),dtype=np.uint8)
        a_seg=np.zeros((len(filenames),1), dtype=np.float64)
        temp_list=[]
        temp_label=[]
        temp_seg=[]        
        for i in range(0,len(filenames)):
            if filenames[i]=="":
                continue
            npydata=np.load("./data/npy_10000/five/"+filenames[i]+".npy")
            np.random.shuffle(npydata)
            if npydata.shape[0]<2048:
                continue
            else:
                #x,y,z 2048 samping
                temp_j_list=[]
                for j in range(0,2048):
                    temp_j_list.append([npydata[j][0],npydata[j][1], npydata[j][2]])
                # seg_label ∈ [0,1]
                temp_j_seg=[0,0,0]
                temp_j_seg[0]=(np.amax(npydata[:,1])-ymin)/(ymax-ymin)
                temp_j_seg[1]=(np.mean(npydata[:,1])-ymin)/(ymax-ymin)
                temp_j_seg[2]=(np.amin(npydata[:,1])-ymin)/(ymax-ymin) 
                    
                temp_list.append(temp_j_list)
                temp_label.append(int(fstr[1])-1)
                temp_seg.append(temp_j_seg)
                
        if len(temp_list) < max_shards:
            for i in range(max_shards-len(temp_list)):
                temp_shuffle_list=temp_list
                temp_shuffle_seg=temp_seg
                rvalue=randrange(len(temp_shuffle_list))
                temp_list.append(temp_shuffle_list[rvalue])
                temp_label.append(int(fstr[1])-1)
                temp_seg.append(temp_shuffle_seg[rvalue])

            
        a_data=np.array(temp_list)
        a_label=np.transpose(np.array(temp_label))
        a_seg=np.array(temp_seg)
        
        target=np.zeros(a_data.shape)
        for i in range(a_data.shape[0]):
            for j in range(a_data.shape[1]):
                for k in range(a_data.shape[2]):
                    target[i][j][k]=a_data[i][j][k]-a_data[i].mean(axis=0)[k]

        f=h5py.File("./data/floatlabel/"+str(fstr[1])+'_'+str(fstr[2])+'_'+str(fstr[3])+".h5",'w')
        data=f.create_dataset("data", data=target)
        label=f.create_dataset("label", data=a_label)
        seg=f.create_dataset("seg", data=a_seg)
        f.close()

# %%
folder=os.listdir("./data/")
f=open("./data/total_files_1.txt","w")
for files in folder:
    if 'h5' in files:
        split=files.split('_')
        if split[0]=='1':
            f.write('%s\n'%files)
f.close()

# %%
with open("./data/total_files_1.txt","r") as f:
    data = f.read().split('\n')
random.shuffle(data)

train_data=data[:1400]
test_data=data[1401:]

train=open("./data/train_files_1.txt","w+")
test=open("./data/test_files_1.txt","w+")

for i in range(len(train_data)):
    train_name=train_data[i]
    train.write("%s\n"%train_name)
    
for i in range(len(test_data)):
    test_name=test_data[i]
    test.write("%s\n"%test_name)

train.close()
test.close()
